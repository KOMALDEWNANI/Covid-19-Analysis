# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('https://raw.githubusercontent.com/WidhyaOrg/datasets/master/covid19.csv')

# %%
df
# Out:
#      Sno      Date State/UnionTerritory  ConfirmedIndianNational  \
# 0      1  30/01/20               Kerala                        1
# 1      2  31/01/20               Kerala                        1
# 2      3  01/02/20               Kerala                        2
# 3      4  02/02/20               Kerala                        3
# 4      5  03/02/20               Kerala                        3
# ..   ...       ...                  ...                      ...
# 265  266  21/03/20    Jammu and Kashmir                        4
# 266  267  21/03/20               Ladakh                       13
# 267  268  21/03/20        Uttar Pradesh                       23
# 268  269  21/03/20          Uttarakhand                        3
# 269  270  21/03/20          West Bengal                        3
#
#      ConfirmedForeignNational  Cured  Deaths
# 0                           0      0       0
# 1                           0      0       0
# 2                           0      0       0
# ...

# %%
df1=df.groupby(['Date'],sort=False).sum()

# %%
df1=df1.drop(['Sno'],axis=1)

# %%
df1
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths
# Date
# 30/01/20                        1                         0      0       0
# 31/01/20                        1                         0      0       0
# 01/02/20                        2                         0      0       0
# 02/02/20                        3                         0      0       0
# 03/02/20                        3                         0      0       0
# 04/02/20                        3                         0      0       0
# 05/02/20                        3                         0      0       0
# 06/02/20                        3                         0      0       0
# 07/02/20                        3                         0      0       0
# 08/02/20                        3                         0      0       0
# 09/02/20                        3                         0      0       0
# ...

# %%
df1['Total Cases']=df1['ConfirmedIndianNational']+df1['ConfirmedForeignNational']+df1['Cured']+df1['Deaths']

# %%
df1
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths  \
# Date
# 30/01/20                        1                         0      0       0
# 31/01/20                        1                         0      0       0
# 01/02/20                        2                         0      0       0
# 02/02/20                        3                         0      0       0
# 03/02/20                        3                         0      0       0
# 04/02/20                        3                         0      0       0
# 05/02/20                        3                         0      0       0
# 06/02/20                        3                         0      0       0
# 07/02/20                        3                         0      0       0
# 08/02/20                        3                         0      0       0
# 09/02/20                        3                         0      0       0
# ...

# %%
df1.reset_index(inplace=True)

# %%
df1
# Out:
#         Date  ConfirmedIndianNational  ConfirmedForeignNational  Cured  \
# 0   30/01/20                        1                         0      0
# 1   31/01/20                        1                         0      0
# 2   01/02/20                        2                         0      0
# 3   02/02/20                        3                         0      0
# 4   03/02/20                        3                         0      0
# 5   04/02/20                        3                         0      0
# 6   05/02/20                        3                         0      0
# 7   06/02/20                        3                         0      0
# 8   07/02/20                        3                         0      0
# 9   08/02/20                        3                         0      0
# 10  09/02/20                        3                         0      0
# 11  10/02/20                        3                         0      0
# ...

# %%
plt.plot(df1['Date'],df1['Total Cases'])
plt.xlabel('Date ')
plt.ylabel('Total Cases')
plt.title('Date vs Total Cases')
plt.show()

# %%
#To calculate rate of increase
sum=0
for i in range(34,52):
    k=(df1.iloc[i-1,5]-df1.iloc[i,5])/df1.iloc[i,5]
    sum=sum+k
r=sum/18
print(r)
# Out:
# -0.15683904720097613

# %%
#Function to predict forecast
def predict(p_o,r,t):
    p_t=p_o+np.exp(r*t) # p_o is the initial value and t is time period in days
    return p_t

# %%
# To find p_t when p_0=31,t=26
p_t=predict(31,r,26)
p_t
# Out:
# 31.01694444500438
